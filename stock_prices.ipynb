# %%
import pandas as pd
import numpy as np

# %%
import yfinance as yf

# %%
#For data visualisation:

import plotly.graph_objs as go

# %%
data = yf.download(tickers='UBER', period='5d', interval = '1m')

data
# Out:
# [*********************100%***********************]  1 of 1 completed
#                                 Open       High        Low      Close  \
# Datetime
# 2023-03-06 09:30:00-05:00  34.584999  34.689999  34.490002  34.500000
# 2023-03-06 09:31:00-05:00  34.510201  34.720001  34.480000  34.639999
# 2023-03-06 09:32:00-05:00  34.639999  34.700001  34.590000  34.689999
# 2023-03-06 09:33:00-05:00  34.680099  34.790001  34.680000  34.750000
# 2023-03-06 09:34:00-05:00  34.770000  34.790001  34.610001  34.617001
# ...                              ...        ...        ...        ...
# 2023-03-10 15:55:00-05:00  31.115000  31.119900  31.075001  31.094999
# 2023-03-10 15:56:00-05:00  31.094999  31.094999  31.059999  31.075001
# 2023-03-10 15:57:00-05:00  31.070000  31.120001  31.070000  31.120001
# 2023-03-10 15:58:00-05:00  31.117001  31.150000  31.110001  31.125000
# 2023-03-10 15:59:00-05:00  31.125000  31.129999  31.090000  31.105000
#
#                            Adj Close  Volume
# Datetime
# 2023-03-06 09:30:00-05:00  34.500000  473117
# 2023-03-06 09:31:00-05:00  34.639999  225809
# 2023-03-06 09:32:00-05:00  34.689999  106129
# 2023-03-06 09:33:00-05:00  34.750000  159049
# 2023-03-06 09:34:00-05:00  34.617001  143003
# ...                              ...     ...
# 2023-03-10 15:55:00-05:00  31.094999  163219
# 2023-03-10 15:56:00-05:00  31.075001  171618
# 2023-03-10 15:57:00-05:00  31.120001  273093
# 2023-03-10 15:58:00-05:00  31.125000  271657
# 2023-03-10 15:59:00-05:00  31.105000  541723
#
# [1950 rows x 6 columns]

# %%
data = yf.download(tickers='GOOGL', period='1d', interval='1m')
#Interval required 1 minute

#declare figure
fig = go.Figure()

#Candlestick
fig.add_trace(go.Candlestick(x=data.index,
                open=data['Open'],
                high=data['High'],
                low=data['Low'],
                close=data['Close'], name = 'market data'))

# Add titles
fig.update_layout(
    title='Google live share price evolution',
    yaxis_title='Stock Price (USD per Shares)')

# X-Axes
fig.update_xaxes(
    rangeslider_visible=True,
    rangeselector=dict(
        buttons=list([
            dict(count=15, label="15m", step="minute", stepmode="backward"),
            dict(count=45, label="45m", step="minute", stepmode="backward"),
            dict(count=1, label="HTD", step="hour", stepmode="todate"),
            dict(count=3, label="3h", step="hour", stepmode="backward"),
            dict(step="all")
        ])
    )
)

#Show
fig.show()
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
import requests
def getTicker(company_name):
    yfinance = "https://query2.finance.yahoo.com/v1/finance/search"
    user_agent = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/108.0.0.0 Safari/537.36'
    params = {"q": company_name, "quotes_count": 1, "country": "United States"}

    res = requests.get(url=yfinance, params=params, headers={'User-Agent': user_agent})
    data = res.json()

    company_code = data['quotes'][0]['symbol']
    return company_code

company1 = input("Enter the name of company: ")

stock_symbol = getTicker(company1)
print(stock_symbol)
# Out:
# AAPL

# %%
import requests

# Enter your Alpha Vantage API key
api_key = 'TYPIYSG66KKSZP4J'

# Enter the stock symbol you want to retrieve details for
symbol = stock_symbol

# Send a request to the Alpha Vantage API and get the JSON response
response = requests.get(f'https://www.alphavantage.co/query?function=GLOBAL_QUOTE&symbol={symbol}&apikey={api_key}')
data = response.json()

# Extract the details from the JSON response
price = data['Global Quote']['05. price']
open_price = data['Global Quote']['02. open']
high_price = data['Global Quote']['03. high']
low_price = data['Global Quote']['04. low']
volume = data['Global Quote']['06. volume']
change_percent = data['Global Quote']['10. change percent']

# Print the details
print(f'Stock Symbol: {symbol}')
print(f'Price: ${price}')
print(f'Open Price: ${open_price}')
print(f'High Price: ${high_price}')
print(f'Low Price: ${low_price}')
print(f'Volume: {volume}')
print(f'Change Percent: {change_percent}')
# Out:
# Stock Symbol: META
# Price: $204.9300
# Open Price: $198.2600
# High Price: $205.7600
# Low Price: $196.0886
# Volume: 50819659
# Change Percent: 3.6308%
